# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Normalize pixel values (0 to 1 range)
x_train, x_test = x_train / 255.0, x_test / 255.0

# Convert labels to one-hot encoding
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# Define the Neural Network Model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),  # Input Layer
    keras.layers.Dense(128, activation='relu'),  # Hidden Layer 1
    keras.layers.Dense(64, activation='relu'),   # Hidden Layer 2
    keras.layers.Dense(10, activation='softmax') # Output Layer (10 classes)
])

# Compile the Model
model.compile(optimizer='sgd',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the Model
history = model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test))

# Evaluate Model Performance
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}")

# Plot Training Loss & Accuracy
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['loss'], label="Training Loss", color='red')
plt.plot(history.history['val_loss'], label="Validation Loss", color='blue')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss Reduction Over Training")
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label="Training Accuracy", color='red')
plt.plot(history.history['val_accuracy'], label="Validation Accuracy", color='blue')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy Improvement Over Training")
plt.legend()

plt.show()

# Predict a Single Image
def predict_single_image(index):
    img = x_test[index]
    plt.imshow(img, cmap="gray")
    plt.title("Actual Digit")
    plt.show()

    img = np.expand_dims(img, axis=0)  # Reshape for model input
    prediction = model.predict(img)
    predicted_digit = np.argmax(prediction)

    print(f"Model Prediction: {predicted_digit}")

# Example: Predicting the first test image
predict_single_image(0)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.6908 - loss: 1.0724 - val_accuracy: 0.9092 - val_loss: 0.3177
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9120 - loss: 0.3137 - val_accuracy: 0.9290 - val_loss: 0.2508
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9279 - loss: 0.2475 - val_accuracy: 0.9401 - val_loss: 0.2120
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9410 - loss: 0.2090 - val_accuracy: 0.9382 - val_loss: 0.1986
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9455 - loss: 0.1869 - val_accuracy: 0.9488 - val_loss: 0.1702
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9522 - loss: 0.1660 - val_accuracy: 0.9525 - val_loss: 0.1595
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9587 - loss: 0.1422 - val_accuracy: 0.9557 - val_loss: 0.1471
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9612 - loss: 0.1348 - val_accuracy: 0.9592 - val_loss: 0.1331
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9650 - loss: 0.1268 - val_accuracy: 0.9606 - val_loss: 0.1304
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9673 - loss: 0.1125 - val_accuracy: 0.9630 - val_loss: 0.1220
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9575 - loss: 0.1403
# Test Accuracy: 0.9630
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Model Prediction: 7
